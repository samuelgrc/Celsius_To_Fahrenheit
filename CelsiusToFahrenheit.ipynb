# %%
import tensorflow as tf
import numpy as np

# %%
celsius = np.array([-40,-10,0,8,15,22,38], dtype = float)
fahrenheit = np.array([-40,14,32,46,59,72,100], dtype = float)

# %%
layer = tf.keras.layers.Dense( units = 1 , input_shape = [1])
model = tf.keras.Sequential([layer])

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss = 'mean_squared_error'
)

# %% [markdown]
# # Training Model

# %%
print('TRAINING!!')
record = model.fit(celsius,fahrenheit, epochs=1000,verbose=False)
print('TRAINED MODEL!!')
# Out:
# TRAINING!!
# TRAINED MODEL!!

# %% [markdown]
# # Statistics

# %%
import matplotlib.pyplot as plt


plt.xlabel('Epoch')
plt.ylabel('magnitude of loss')
plt.plot(record.history["loss"])

# %% [markdown]
# # Prediction

# %%
result = model.predict([50.0])
print(f"The result is " + str(result) + "fahrenheit")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# The result is [[121.849945]]fahrenheit

# %% [markdown]
# # internal Variables

# %%
print(layer.get_weights())
# Out:
# [array([[1.7979494]], dtype=float32), array([31.95248], dtype=float32)]

# %% [markdown]
# # Celsius to fahrenheit formula

# %% [markdown]
# Fahrenheit = Celsius * 1.8 + 32
